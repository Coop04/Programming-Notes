# %%
from PIL import Image
import os

# %%
image1 = Image.open('A.jpg')

# %%
image1.show() # to open up the image

# %%
# image1.save('A1.png') # to create a png

# %%
for f in os.listdir('.'): # . for the current directory
    if f.endswith('.jpg'):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.save(f'png/{fn}.png')
