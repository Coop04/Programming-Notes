# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
# 3           Employed, full-time     Remote  Apples
# 4            Student, full-time        NaN  Apples
# 5            Student, full-time        NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# ...

# %%
filt = (df['Country']=='India')
india_df = df.loc[filt]
india_df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 18                             I am a developer by profession
# 59          I am not primarily a developer, but I write co...
# 76                                      I am learning to code
# 90                                      I am learning to code
# 97                             I am a developer by profession
#
#                         Age  \
# ResponseId
# 18          18-24 years old
# 59          18-24 years old
# 76          25-34 years old
# 90          25-34 years old
# 97          25-34 years old
#
#                                                    Employment RemoteWork  \
# ResponseId
# 18          Independent contractor, freelancer, or self-em...     Remote
# 59                                         Student, full-time        NaN
# 76                         Not employed, but looking for work        NaN
# 90                                        Employed, full-time  In-person
# ...

# %% [markdown]
# # .csv

# %%
# to export this file to csv file
india_df.to_csv('data/Modified.csv')

# %% [markdown]
# # .tsv

# %%
# to use custom seperator (instead of comma (csv))
india_df.to_csv('data/Modified.tsv', sep='\t') # csv to tsv and sep values can be anything like '-', '_', '.' etc

# %% [markdown]
# # to Excel

# %%
# to write to excel

# %% [markdown]
# # .json

# %%
india_df.to_json('data/Modified.json') # by default it is a dictionary like json

# %%
# to make json to list like form instead of dictionary
india_df.to_json('data/Modified1.json', orient='records', lines=True)

# %%
# to read the json file (which is in the similar format as above)
test = pd.read_json('data/Modified1.json', orient='records', lines=True)
test.head()
# Out:
#                                           MainBranch              Age  \
# 0                     I am a developer by profession  18-24 years old
# 1  I am not primarily a developer, but I write co...  18-24 years old
# 2                              I am learning to code  25-34 years old
# 3                              I am learning to code  25-34 years old
# 4                     I am a developer by profession  25-34 years old
#
#                                           Employment RemoteWork   Check  \
# 0  Independent contractor, freelancer, or self-em...     Remote  Apples
# 1                                 Student, full-time       None  Apples
# 2                 Not employed, but looking for work       None  Apples
# 3                                Employed, full-time  In-person  Apples
# 4                                Employed, full-time     Remote  Apples
#
#                                     CodingActivities  \
# 0  Hobby;Professional development or self-paced l...
# ...

# %% [markdown]
# # from url

# %%
posts_df = pd.read_json('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Flask_Blog/snippets/posts.json')

# %%
posts_df.head()
# Out:
#                           title  \
# 0               My Updated Post
# 1                 A Second Post
# 2  Top 5 Programming Lanaguages
# 3  Sublime Text Tips and Tricks
# 4              Best Python IDEs
#
#                                              content  user_id
# 0    My first updated post!\r\n\r\nThis is exciting!        1
# 1            This is a post from a different user...        2
# 2  Te melius apeirian postulant cum, labitur admo...        1
# 3  Ea vix dico modus voluptatibus, mel iudico sua...        1
# 4  Elit contentiones nam no, sea ut consul adipis...        1
